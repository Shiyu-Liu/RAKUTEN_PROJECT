# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Rakuten_for_colab/image_train_zoomed.zip /content/

# !mkdir -p /content/image_train_zoomed
# Unzip into it
# !unzip -q /content/image_train_zoomed.zip -d /content/image_train_zoomed/

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.applications import ResNet50, MobileNetV2, EfficientNetB0, ConvNeXtTiny
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
#import tensorflow_addons as tfa
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import time

# %%
df_train_balanced = pd.read_csv("drive/MyDrive/Rakuten_for_colab/input_data/df_train_balanced.csv")
val_df = pd.read_csv("drive/MyDrive/Rakuten_for_colab/input_data/val_df.csv")
num_classes = df_train_balanced["label"].nunique()
num_classes
# Out:
# 27

# %%
df_train_balanced.head()
# Out:
#                                          designation  \
# 0  Magnet Père Dodu - Régions D'europe - 48 - Orl...
# 1  Lot De 3 Revues Aquarium Magazine Et 1 Aquariu...
# 2  Living Room Dressing Table Desktop Sundries St...
# 3  Rc280 Telecommande Pour Tcl Roku Tlc Tv 40fs37...
# 4  Tout-petit bébé Enfants 15pc Chaussettes bébé ...
#
#                                          description   productid     imageid  \
# 0                                                NaN    73192148   844757331
# 1                                                NaN  3744929595  1240241895
# 2  Living Room Dressing Table Desktop Sundries St...  4057530663  1282883250
# 3  Description:  <br />Type d&#39;element: Teleco...  4108382685  1292292689
# 4  Tout-petit bébé Enfants 15pc Chaussettes bébé ...  3898729891  1261430706
#
#    content_ratio  prdtypecode  label  augmented
# 0       0.666000         1140      4      False
# 1       0.860000         2403     19      False
# 2       1.000000         1560     13      False
# 3       0.611184           50      2      False
# 4       0.676396         1301     10       True

# %% [markdown]
# ## Verify all images are present

# %%
image_dir = 'drive/MyDrive/Rakuten_for_colab/image_train_zoomed/'

df_train_balanced['image_exists'] = False

for index, row in df_train_balanced.iterrows():
    image_id = row['imageid']
    product_id = row['productid']
    image_filename = f"image_{image_id}_product_{product_id}.jpg"
    image_path = os.path.join(image_dir, image_filename)

    if os.path.exists(image_path):
        df_train_balanced.at[index, 'image_exists'] = True

print("Number of rows with images:", df_train_balanced['image_exists'].sum())

missing_images = df_train_balanced[~df_train_balanced['image_exists']]
print("Rows with missing images:")
print(missing_images)
# Out:
# Number of rows with images: 71199
# Rows with missing images:
# Empty DataFrame
# Columns: [designation, description, productid, imageid, content_ratio, prdtypecode, label, augmented, image_exists]
# Index: []

# %%
val_df['image_exists'] = False
for index, row in val_df.iterrows():
    image_id = row['imageid']
    product_id = row['productid']
    image_filename = f"image_{image_id}_product_{product_id}.jpg"
    image_path = os.path.join(image_dir, image_filename)

    # Check if the image file exists
    if os.path.exists(image_path):
        val_df.at[index, 'image_exists'] = True

# You can now check the 'image_exists' column
# To see how many rows have a corresponding image:
print("Number of rows with images:", val_df['image_exists'].sum())

# To see rows that do not have an image:
missing_images = val_df[~val_df['image_exists']]
print("Rows with missing images:")
print(missing_images)
# Out:
# Number of rows with images: 16902
# Rows with missing images:
# Empty DataFrame
# Columns: [designation, description, productid, imageid, content_ratio, prdtypecode, label, image_exists]
# Index: []

# %%
base_path = "/content/image_train_zoomed/"

# %% [markdown]
# ## Helper functions

# %%
def plot_history(history_dict):
    epochs = range(1, len(history_dict['loss']) + 1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Plot Loss
    ax1.plot(epochs, history_dict['loss'], label='Train Loss')
    ax1.plot(epochs, history_dict['val_loss'], label='Val Loss')
    ax1.set_title('Loss over Epochs', fontsize=16)
    ax1.set_xlabel('Epoch', fontsize=14)
    ax1.set_ylabel('Loss', fontsize=14)
    ax1.legend(fontsize=14)

    # Plot Accuracy
    ax2.plot(epochs, history_dict['sparse_categorical_accuracy'], label='Train Accuracy')
    ax2.plot(epochs, history_dict['val_sparse_categorical_accuracy'], label='Val Accuracy')
    ax2.set_title('Accuracy over Epochs', fontsize=16)
    ax2.set_xlabel('Epoch', fontsize=14)
    ax2.set_ylabel('Accuracy', fontsize=14)
    ax2.legend(fontsize=14)

    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics import classification_report

def evaluate_model(model, val_ds):
    y_true = []
    y_pred = []

    for images, labels in val_ds:
        # Predict on the batch
        preds = model.predict(images, verbose=0)

        # Convert predictions to class indices
        batch_pred = np.argmax(preds, axis=1)

        # Convert true labels to class indices
        if len(labels.shape) > 1 and labels.shape[1] > 1:
            batch_true = np.argmax(labels.numpy(), axis=1)
        else:
            batch_true = labels.numpy()

        y_pred.extend(batch_pred)
        y_true.extend(batch_true)

    # Convert to arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Generate class names
    num_classes = model.output_shape[-1]
    class_names = [f'class_{i}' for i in range(num_classes)]

    # Print classification report
    report = classification_report(y_true, y_pred, target_names=class_names)
    print(report)

# %%
def plot_history_comp(model1, model2, model1_name="Model 1", model2_name="Model 2"):
    history1 = model1.history.history
    history2 = model2.history.history

    # Plot Loss
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history1['loss'], label=f'{model1_name} - Train')
    plt.plot(history1['val_loss'], label=f'{model1_name} - Val')
    plt.plot(history2['loss'], label=f'{model2_name} - Train')
    plt.plot(history2['val_loss'], label=f'{model2_name} - Val')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history1['sparse_categorical_accuracy'], label=f'{model1_name} - Train')
    plt.plot(history1['val_sparse_categorical_accuracy'], label=f'{model1_name} - Val')
    plt.plot(history2['sparse_categorical_accuracy'], label=f'{model2_name} - Train')
    plt.plot(history2['val_sparse_categorical_accuracy'], label=f'{model2_name} - Val')
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## EfficientNetB0

# %%
def create_datasets(base_path, train_df, val_df, batch_size):
    def preprocess_image(imageid, productid, label, augmented):
        def _load_image(image_path):
            img = tf.io.read_file(image_path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [224, 224])
            img = tf.keras.applications.efficientnet.preprocess_input(img)
            return img

        image_path = tf.strings.join([
            base_path,
            "image_",
            imageid,
            "_product_",
            productid,
            ".jpg"
        ])

        image = _load_image(image_path)

        def apply_augmentation(img):
            img = tf.image.random_flip_left_right(img)
            img = tf.image.random_brightness(img, max_delta=0.1)
            translations = tf.cast(tf.random.uniform([2], -10, 10), tf.int32)
            img = tf.roll(img, shift=translations[0], axis=0)  
            img = tf.roll(img, shift=translations[1], axis=1)  
            return img

        image = tf.cond(augmented, lambda: apply_augmentation(image), lambda: image)

        return image, label

    # Prepare train dataset with augmentation flags from train_df
    train_image_ids = train_df["imageid"].astype(str).values
    train_product_ids = train_df["productid"].astype(str).values
    train_labels = train_df["label"].values
    train_aug_flags = train_df["augmented"].astype(bool).values

    train_ds = tf.data.Dataset.from_tensor_slices(
        (train_image_ids, train_product_ids, train_labels, train_aug_flags)
    )
    train_ds = train_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    # Prepare validation dataset (no augmentation)
    val_image_ids = val_df["imageid"].astype(str).values
    val_product_ids = val_df["productid"].astype(str).values
    val_labels = val_df["label"].values
    val_aug_flags = [False] * len(val_df)

    val_ds = tf.data.Dataset.from_tensor_slices(
        (val_image_ids, val_product_ids, val_labels, val_aug_flags)
    )
    val_ds = val_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds

# %%
train_ds, val_ds = create_datasets(base_path, df_train_balanced, val_df, 128)

# %%
# Model definition
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#for layer in base_model.layers[-5:]:
#    if not isinstance(layer, tf.keras.layers.BatchNormalization):
#        layer.trainable = True

efficientnetb0_b128l0 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

efficientnetb0_b128l0.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

#Callbacks

checkpoint = ModelCheckpoint(
    'efficientnetb0_b128l0_best_model.keras',                
    monitor='val_loss',             
    mode='min',                    
    save_best_only=True,           
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.1,
        min_lr=1e-7,
        verbose=1
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
start_time = time.time()

efficientnetb0_b128l0_history = efficientnetb0_b128l0.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.6274 - sparse_categorical_accuracy: 0.0855
# Epoch 1: val_loss improved from inf to 4.89336, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 84s 109ms/step - loss: 6.6264 - sparse_categorical_accuracy: 0.0856 - val_loss: 4.8934 - val_sparse_categorical_accuracy: 0.3649 - learning_rate: 1.0000e-04
# Epoch 2/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.9403 - sparse_categorical_accuracy: 0.2461
# Epoch 2: val_loss improved from 4.89336 to 3.92187, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 4.9399 - sparse_categorical_accuracy: 0.2462 - val_loss: 3.9219 - val_sparse_categorical_accuracy: 0.4294 - learning_rate: 1.0000e-04
# Epoch 3/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.0629 - sparse_categorical_accuracy: 0.3266
# Epoch 3: val_loss improved from 3.92187 to 3.28661, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 4.0626 - sparse_categorical_accuracy: 0.3266 - val_loss: 3.2866 - val_sparse_categorical_accuracy: 0.4653 - learning_rate: 1.0000e-04
# Epoch 4/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.4536 - sparse_categorical_accuracy: 0.3721
# Epoch 4: val_loss improved from 3.28661 to 2.82879, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 3.4534 - sparse_categorical_accuracy: 0.3721 - val_loss: 2.8288 - val_sparse_categorical_accuracy: 0.4939 - learning_rate: 1.0000e-04
# Epoch 5/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.0211 - sparse_categorical_accuracy: 0.4068
# Epoch 5: val_loss improved from 2.82879 to 2.52812, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 3.0209 - sparse_categorical_accuracy: 0.4068 - val_loss: 2.5281 - val_sparse_categorical_accuracy: 0.5080 - learning_rate: 1.0000e-04
# Epoch 6/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.7244 - sparse_categorical_accuracy: 0.4303
# Epoch 6: val_loss improved from 2.52812 to 2.31430, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.7243 - sparse_categorical_accuracy: 0.4304 - val_loss: 2.3143 - val_sparse_categorical_accuracy: 0.5208 - learning_rate: 1.0000e-04
# Epoch 7/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.5087 - sparse_categorical_accuracy: 0.4475
# Epoch 7: val_loss improved from 2.31430 to 2.17351, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.5086 - sparse_categorical_accuracy: 0.4475 - val_loss: 2.1735 - val_sparse_categorical_accuracy: 0.5286 - learning_rate: 1.0000e-04
# Epoch 8/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.3554 - sparse_categorical_accuracy: 0.4612
# Epoch 8: val_loss improved from 2.17351 to 2.07188, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.3554 - sparse_categorical_accuracy: 0.4612 - val_loss: 2.0719 - val_sparse_categorical_accuracy: 0.5354 - learning_rate: 1.0000e-04
# Epoch 9/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.2486 - sparse_categorical_accuracy: 0.4726
# Epoch 9: val_loss improved from 2.07188 to 2.00539, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.2486 - sparse_categorical_accuracy: 0.4726 - val_loss: 2.0054 - val_sparse_categorical_accuracy: 0.5373 - learning_rate: 1.0000e-04
# Epoch 10/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.1690 - sparse_categorical_accuracy: 0.4838
# Epoch 10: val_loss improved from 2.00539 to 1.96813, saving model to efficientnetb0_b128l0_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.1690 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.9681 - val_sparse_categorical_accuracy: 0.5407 - learning_rate: 5.0000e-05
# Epoch 11/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.1353 - sparse_categorical_accuracy: 0.4890
# Epoch 11: val_loss improved from 1.96813 to 1.94461, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.1353 - sparse_categorical_accuracy: 0.4890 - val_loss: 1.9446 - val_sparse_categorical_accuracy: 0.5411 - learning_rate: 5.0000e-05
# Epoch 12/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.1127 - sparse_categorical_accuracy: 0.4890
# Epoch 12: val_loss improved from 1.94461 to 1.93226, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.1127 - sparse_categorical_accuracy: 0.4890 - val_loss: 1.9323 - val_sparse_categorical_accuracy: 0.5431 - learning_rate: 2.5000e-05
# Epoch 13/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0945 - sparse_categorical_accuracy: 0.4898
# Epoch 13: val_loss improved from 1.93226 to 1.92702, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.0944 - sparse_categorical_accuracy: 0.4898 - val_loss: 1.9270 - val_sparse_categorical_accuracy: 0.5432 - learning_rate: 1.2500e-05
# Epoch 14/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0813 - sparse_categorical_accuracy: 0.4911
# Epoch 14: val_loss improved from 1.92702 to 1.92414, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.0813 - sparse_categorical_accuracy: 0.4911 - val_loss: 1.9241 - val_sparse_categorical_accuracy: 0.5433 - learning_rate: 6.2500e-06
# Epoch 15/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0794 - sparse_categorical_accuracy: 0.4955
# Epoch 15: val_loss improved from 1.92414 to 1.92267, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 51ms/step - loss: 2.0794 - sparse_categorical_accuracy: 0.4955 - val_loss: 1.9227 - val_sparse_categorical_accuracy: 0.5430 - learning_rate: 3.1250e-06
# Epoch 16/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0810 - sparse_categorical_accuracy: 0.4919
# Epoch 16: val_loss improved from 1.92267 to 1.92176, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 51ms/step - loss: 2.0809 - sparse_categorical_accuracy: 0.4919 - val_loss: 1.9218 - val_sparse_categorical_accuracy: 0.5430 - learning_rate: 1.5625e-06
# Epoch 17/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0721 - sparse_categorical_accuracy: 0.4963
# Epoch 17: val_loss improved from 1.92176 to 1.92138, saving model to efficientnetb0_b128l0_best_model.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.0721 - sparse_categorical_accuracy: 0.4963 - val_loss: 1.9214 - val_sparse_categorical_accuracy: 0.5431 - learning_rate: 7.8125e-07
# Training time: 9.12 min

# %%
plot_history(efficientnetb0_b128l0_history.history)

# %%
evaluate_model(efficientnetb0_b128l0, val_ds)
# Out:
#               precision    recall  f1-score   support
#
#      class_0       0.39      0.33      0.35       622
#      class_1       0.52      0.41      0.46       498
#      class_2       0.29      0.41      0.34       334
#      class_3       0.43      0.80      0.56       166
#      class_4       0.55      0.65      0.59       527
#      class_5       0.87      0.86      0.87       786
#      class_6       0.27      0.42      0.33       151
#      class_7       0.48      0.21      0.29       973
#      class_8       0.31      0.21      0.25       413
#      class_9       0.60      0.61      0.61      1007
#     class_10       0.36      0.77      0.49       157
#     class_11       0.33      0.35      0.34       496
#     class_12       0.41      0.39      0.40       643
#     class_13       0.63      0.51      0.57      1014
#     class_14       0.79      0.77      0.78       860
#     class_15       0.37      0.81      0.51       159
#     class_16       0.53      0.43      0.47       998
#     class_17       0.24      0.58      0.34       164
#     class_18       0.67      0.71      0.69       950
#     class_19       0.69      0.53      0.60       951
#     class_20       0.36      0.55      0.44       283
#     class_21       0.66      0.63      0.64       985
#     class_22       0.35      0.39      0.37       517
#     class_23       0.84      0.64      0.73      2027
#     class_24       0.27      0.37      0.31       495
#     class_25       0.47      0.66      0.55       552
#     class_26       0.27      0.74      0.40       174
#
#     accuracy                           0.54     16902
#    macro avg       0.48      0.55      0.49     16902
# weighted avg       0.57      0.54      0.55     16902

# %% [markdown]
# ## EfficientNetB0 L5

# %%
# Model definition
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-5:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

efficientnetb0_b128l5 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

efficientnetb0_b128l5.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'efficientnetb0_b128l5_best_model.keras',               
    monitor='val_loss',            
    mode='min',                   
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.1,
        min_lr=1e-7,
        verbose=1
)

# %%
start_time = time.time()

efficientnetb0_b128l5_history = efficientnetb0_b128l5.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 6.2996 - sparse_categorical_accuracy: 0.1222
# Epoch 1: val_loss improved from inf to 4.52496, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 70s 87ms/step - loss: 6.2986 - sparse_categorical_accuracy: 0.1223 - val_loss: 4.5250 - val_sparse_categorical_accuracy: 0.4440 - learning_rate: 1.0000e-04
# Epoch 2/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.6205 - sparse_categorical_accuracy: 0.3258
# Epoch 2: val_loss improved from 4.52496 to 3.62370, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 4.6201 - sparse_categorical_accuracy: 0.3258 - val_loss: 3.6237 - val_sparse_categorical_accuracy: 0.5020 - learning_rate: 1.0000e-04
# Epoch 3/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.7787 - sparse_categorical_accuracy: 0.4010
# Epoch 3: val_loss improved from 3.62370 to 3.03950, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 3.7785 - sparse_categorical_accuracy: 0.4011 - val_loss: 3.0395 - val_sparse_categorical_accuracy: 0.5247 - learning_rate: 1.0000e-04
# Epoch 4/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.1863 - sparse_categorical_accuracy: 0.4455
# Epoch 4: val_loss improved from 3.03950 to 2.61847, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 3.1861 - sparse_categorical_accuracy: 0.4455 - val_loss: 2.6185 - val_sparse_categorical_accuracy: 0.5439 - learning_rate: 1.0000e-04
# Epoch 5/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.7571 - sparse_categorical_accuracy: 0.4814
# Epoch 5: val_loss improved from 2.61847 to 2.32028, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.7569 - sparse_categorical_accuracy: 0.4814 - val_loss: 2.3203 - val_sparse_categorical_accuracy: 0.5589 - learning_rate: 1.0000e-04
# Epoch 6/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.4398 - sparse_categorical_accuracy: 0.5067
# Epoch 6: val_loss improved from 2.32028 to 2.11138, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.4396 - sparse_categorical_accuracy: 0.5068 - val_loss: 2.1114 - val_sparse_categorical_accuracy: 0.5680 - learning_rate: 1.0000e-04
# Epoch 7/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.2026 - sparse_categorical_accuracy: 0.5351
# Epoch 7: val_loss improved from 2.11138 to 1.95472, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.2025 - sparse_categorical_accuracy: 0.5351 - val_loss: 1.9547 - val_sparse_categorical_accuracy: 0.5780 - learning_rate: 1.0000e-04
# Epoch 8/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.0183 - sparse_categorical_accuracy: 0.5614
# Epoch 8: val_loss improved from 1.95472 to 1.84559, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 2.0182 - sparse_categorical_accuracy: 0.5614 - val_loss: 1.8456 - val_sparse_categorical_accuracy: 0.5871 - learning_rate: 1.0000e-04
# Epoch 9/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.8711 - sparse_categorical_accuracy: 0.5798
# Epoch 9: val_loss improved from 1.84559 to 1.76829, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.5798 - val_loss: 1.7683 - val_sparse_categorical_accuracy: 0.5927 - learning_rate: 1.0000e-04
# Epoch 10/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.7604 - sparse_categorical_accuracy: 0.5980
# Epoch 10: val_loss improved from 1.76829 to 1.72762, saving model to efficientnetb0_b128l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.7604 - sparse_categorical_accuracy: 0.5980 - val_loss: 1.7276 - val_sparse_categorical_accuracy: 0.5967 - learning_rate: 5.0000e-05
# Epoch 11/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.7051 - sparse_categorical_accuracy: 0.6102
# Epoch 11: val_loss improved from 1.72762 to 1.70064, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.7051 - sparse_categorical_accuracy: 0.6102 - val_loss: 1.7006 - val_sparse_categorical_accuracy: 0.6003 - learning_rate: 5.0000e-05
# Epoch 12/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6611 - sparse_categorical_accuracy: 0.6176
# Epoch 12: val_loss improved from 1.70064 to 1.68632, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.6610 - sparse_categorical_accuracy: 0.6176 - val_loss: 1.6863 - val_sparse_categorical_accuracy: 0.6028 - learning_rate: 2.5000e-05
# Epoch 13/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6343 - sparse_categorical_accuracy: 0.6244
# Epoch 13: val_loss improved from 1.68632 to 1.67486, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.6343 - sparse_categorical_accuracy: 0.6244 - val_loss: 1.6749 - val_sparse_categorical_accuracy: 0.6048 - learning_rate: 1.2500e-05
# Epoch 14/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6207 - sparse_categorical_accuracy: 0.6271
# Epoch 14: val_loss improved from 1.67486 to 1.67314, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.6207 - sparse_categorical_accuracy: 0.6271 - val_loss: 1.6731 - val_sparse_categorical_accuracy: 0.6057 - learning_rate: 6.2500e-06
# Epoch 15/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6096 - sparse_categorical_accuracy: 0.6329
# Epoch 15: val_loss improved from 1.67314 to 1.67135, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.6095 - sparse_categorical_accuracy: 0.6329 - val_loss: 1.6713 - val_sparse_categorical_accuracy: 0.6058 - learning_rate: 3.1250e-06
# Epoch 16/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.6292
# Epoch 16: val_loss improved from 1.67135 to 1.67051, saving model to efficientnetb0_b128l5_best_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.6292 - val_loss: 1.6705 - val_sparse_categorical_accuracy: 0.6063 - learning_rate: 1.5625e-06
# Training time: 8.50 min

# %%
plot_history(efficientnetb0_b128l5_history.history)

# %% [markdown]
# ## EfficientNetB0 L5 LR

# %%
# Model definition
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-5:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

efficientnetb0_b128l5lr = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

efficientnetb0_b128l5lr.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'efficientnetb0_b128l5lr_best_model.keras',               
    monitor='val_loss',             
    mode='min',                     
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.05,
        min_lr=1e-7,
        verbose=1
)

# %%
start_time = time.time()

efficientnetb0_b128l5lr_history = efficientnetb0_b128l5lr.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 6.3735 - sparse_categorical_accuracy: 0.1211
# Epoch 1: val_loss improved from inf to 4.56119, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 70s 87ms/step - loss: 6.3724 - sparse_categorical_accuracy: 0.1212 - val_loss: 4.5612 - val_sparse_categorical_accuracy: 0.4308 - learning_rate: 1.0000e-04
# Epoch 2/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.6528 - sparse_categorical_accuracy: 0.3241
# Epoch 2: val_loss improved from 4.56119 to 3.67854, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 4.6520 - sparse_categorical_accuracy: 0.3242 - val_loss: 3.6785 - val_sparse_categorical_accuracy: 0.4904 - learning_rate: 1.0000e-04
# Epoch 3/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.8198 - sparse_categorical_accuracy: 0.3960
# Epoch 3: val_loss improved from 3.67854 to 3.09310, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 3.8195 - sparse_categorical_accuracy: 0.3960 - val_loss: 3.0931 - val_sparse_categorical_accuracy: 0.5208 - learning_rate: 1.0000e-04
# Epoch 4/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.2219 - sparse_categorical_accuracy: 0.4421
# Epoch 4: val_loss improved from 3.09310 to 2.66835, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 3.2217 - sparse_categorical_accuracy: 0.4421 - val_loss: 2.6684 - val_sparse_categorical_accuracy: 0.5392 - learning_rate: 1.0000e-04
# Epoch 5/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.8040 - sparse_categorical_accuracy: 0.4731
# Epoch 5: val_loss improved from 2.66835 to 2.34910, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 2.8038 - sparse_categorical_accuracy: 0.4731 - val_loss: 2.3491 - val_sparse_categorical_accuracy: 0.5608 - learning_rate: 1.0000e-04
# Epoch 6/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.4779 - sparse_categorical_accuracy: 0.4993
# Epoch 6: val_loss improved from 2.34910 to 2.13582, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - loss: 2.4778 - sparse_categorical_accuracy: 0.4993 - val_loss: 2.1358 - val_sparse_categorical_accuracy: 0.5673 - learning_rate: 1.0000e-04
# Epoch 7/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.2270 - sparse_categorical_accuracy: 0.5323
# Epoch 7: val_loss improved from 2.13582 to 1.98036, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 53ms/step - loss: 2.2270 - sparse_categorical_accuracy: 0.5323 - val_loss: 1.9804 - val_sparse_categorical_accuracy: 0.5754 - learning_rate: 1.0000e-04
# Epoch 8/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.0435 - sparse_categorical_accuracy: 0.5552
# Epoch 8: val_loss improved from 1.98036 to 1.86795, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 53ms/step - loss: 2.0434 - sparse_categorical_accuracy: 0.5552 - val_loss: 1.8680 - val_sparse_categorical_accuracy: 0.5854 - learning_rate: 1.0000e-04
# Epoch 9/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.8957 - sparse_categorical_accuracy: 0.5784
# Epoch 9: val_loss improved from 1.86795 to 1.78345, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.8957 - sparse_categorical_accuracy: 0.5784 - val_loss: 1.7835 - val_sparse_categorical_accuracy: 0.5933 - learning_rate: 1.0000e-04
# Epoch 10/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.7717 - sparse_categorical_accuracy: 0.5993
# Epoch 10: val_loss improved from 1.78345 to 1.71992, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.7717 - sparse_categorical_accuracy: 0.5993 - val_loss: 1.7199 - val_sparse_categorical_accuracy: 0.5958 - learning_rate: 1.0000e-04
# Epoch 11/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6826 - sparse_categorical_accuracy: 0.6141
# Epoch 11: val_loss improved from 1.71992 to 1.67878, saving model to efficientnetb0_b128l5lr_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.6826 - sparse_categorical_accuracy: 0.6141 - val_loss: 1.6788 - val_sparse_categorical_accuracy: 0.6026 - learning_rate: 1.0000e-04
# Epoch 12/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5991 - sparse_categorical_accuracy: 0.6314
# Epoch 12: val_loss improved from 1.67878 to 1.64891, saving model to efficientnetb0_b128l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.5991 - sparse_categorical_accuracy: 0.6315 - val_loss: 1.6489 - val_sparse_categorical_accuracy: 0.6092 - learning_rate: 5.0000e-05
# Epoch 13/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5492 - sparse_categorical_accuracy: 0.6450
# Epoch 13: val_loss improved from 1.64891 to 1.63701, saving model to efficientnetb0_b128l5lr_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.5492 - sparse_categorical_accuracy: 0.6450 - val_loss: 1.6370 - val_sparse_categorical_accuracy: 0.6096 - learning_rate: 5.0000e-05
# Epoch 14/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5190 - sparse_categorical_accuracy: 0.6507
# Epoch 14: val_loss improved from 1.63701 to 1.61937, saving model to efficientnetb0_b128l5lr_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.5190 - sparse_categorical_accuracy: 0.6507 - val_loss: 1.6194 - val_sparse_categorical_accuracy: 0.6135 - learning_rate: 2.5000e-05
# Epoch 15/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4914 - sparse_categorical_accuracy: 0.6563
# Epoch 15: val_loss improved from 1.61937 to 1.61404, saving model to efficientnetb0_b128l5lr_best_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.4914 - sparse_categorical_accuracy: 0.6563 - val_loss: 1.6140 - val_sparse_categorical_accuracy: 0.6131 - learning_rate: 1.2500e-05
# Epoch 16/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4801 - sparse_categorical_accuracy: 0.6596
# Epoch 16: val_loss improved from 1.61404 to 1.61303, saving model to efficientnetb0_b128l5lr_best_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.4801 - sparse_categorical_accuracy: 0.6596 - val_loss: 1.6130 - val_sparse_categorical_accuracy: 0.6125 - learning_rate: 6.2500e-06
# Epoch 17/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4773 - sparse_categorical_accuracy: 0.6613
# Epoch 17: val_loss improved from 1.61303 to 1.61060, saving model to efficientnetb0_b128l5lr_best_model.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - loss: 1.4773 - sparse_categorical_accuracy: 0.6613 - val_loss: 1.6106 - val_sparse_categorical_accuracy: 0.6133 - learning_rate: 3.1250e-06
# Training time: 8.99 min

# %%
plot_history_comp(efficientnetb0_b128l5, efficientnetb0_b128l5lr,
                      model1_name="efficientnetb0_b128l5",
                      model2_name="efficientnetb0_b128l5lr")

# %% [markdown]
# ## EfficientNetB0 L10

# %%
# Model definition
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-10:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

efficientnetb0_b128l10 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

efficientnetb0_b128l10.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'efficientnetb0_b128l10_best_model.keras',               
    monitor='val_loss',            
    mode='min',                     
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.1,
        min_lr=1e-7,
        verbose=1
)

# %%
start_time = time.time()

efficientnetb0_b128l10_history = efficientnetb0_b128l10.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 6.3375 - sparse_categorical_accuracy: 0.1269
# Epoch 1: val_loss improved from inf to 4.54965, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 72s 90ms/step - loss: 6.3365 - sparse_categorical_accuracy: 0.1270 - val_loss: 4.5497 - val_sparse_categorical_accuracy: 0.4373 - learning_rate: 1.0000e-04
# Epoch 2/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.6585 - sparse_categorical_accuracy: 0.3261
# Epoch 2: val_loss improved from 4.54965 to 3.68324, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 4.6581 - sparse_categorical_accuracy: 0.3262 - val_loss: 3.6832 - val_sparse_categorical_accuracy: 0.4904 - learning_rate: 1.0000e-04
# Epoch 3/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.8046 - sparse_categorical_accuracy: 0.3987
# Epoch 3: val_loss improved from 3.68324 to 3.07900, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 3.8043 - sparse_categorical_accuracy: 0.3987 - val_loss: 3.0790 - val_sparse_categorical_accuracy: 0.5229 - learning_rate: 1.0000e-04
# Epoch 4/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.1876 - sparse_categorical_accuracy: 0.4502
# Epoch 4: val_loss improved from 3.07900 to 2.63023, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 3.1874 - sparse_categorical_accuracy: 0.4502 - val_loss: 2.6302 - val_sparse_categorical_accuracy: 0.5446 - learning_rate: 1.0000e-04
# Epoch 5/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.7481 - sparse_categorical_accuracy: 0.4821
# Epoch 5: val_loss improved from 2.63023 to 2.32162, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 2.7480 - sparse_categorical_accuracy: 0.4822 - val_loss: 2.3216 - val_sparse_categorical_accuracy: 0.5577 - learning_rate: 1.0000e-04
# Epoch 6/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.4154 - sparse_categorical_accuracy: 0.5148
# Epoch 6: val_loss improved from 2.32162 to 2.10076, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 2.4153 - sparse_categorical_accuracy: 0.5149 - val_loss: 2.1008 - val_sparse_categorical_accuracy: 0.5721 - learning_rate: 1.0000e-04
# Epoch 7/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.1730 - sparse_categorical_accuracy: 0.5435
# Epoch 7: val_loss improved from 2.10076 to 1.94958, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 2.1729 - sparse_categorical_accuracy: 0.5435 - val_loss: 1.9496 - val_sparse_categorical_accuracy: 0.5792 - learning_rate: 1.0000e-04
# Epoch 8/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.9766 - sparse_categorical_accuracy: 0.5700
# Epoch 8: val_loss improved from 1.94958 to 1.84149, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.9765 - sparse_categorical_accuracy: 0.5700 - val_loss: 1.8415 - val_sparse_categorical_accuracy: 0.5847 - learning_rate: 1.0000e-04
# Epoch 9/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.8411 - sparse_categorical_accuracy: 0.5887
# Epoch 9: val_loss improved from 1.84149 to 1.75485, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.8410 - sparse_categorical_accuracy: 0.5888 - val_loss: 1.7548 - val_sparse_categorical_accuracy: 0.5960 - learning_rate: 1.0000e-04
# Epoch 10/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7152 - sparse_categorical_accuracy: 0.6131
# Epoch 10: val_loss improved from 1.75485 to 1.71017, saving model to efficientnetb0_b128l10_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 31s 55ms/step - loss: 1.7151 - sparse_categorical_accuracy: 0.6132 - val_loss: 1.7102 - val_sparse_categorical_accuracy: 0.5991 - learning_rate: 5.0000e-05
# Epoch 11/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6634 - sparse_categorical_accuracy: 0.6215
# Epoch 11: val_loss improved from 1.71017 to 1.68328, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.6633 - sparse_categorical_accuracy: 0.6215 - val_loss: 1.6833 - val_sparse_categorical_accuracy: 0.6029 - learning_rate: 5.0000e-05
# Epoch 12/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6038 - sparse_categorical_accuracy: 0.6329
# Epoch 12: val_loss improved from 1.68328 to 1.66868, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.6038 - sparse_categorical_accuracy: 0.6330 - val_loss: 1.6687 - val_sparse_categorical_accuracy: 0.6035 - learning_rate: 2.5000e-05
# Epoch 13/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5843 - sparse_categorical_accuracy: 0.6397
# Epoch 13: val_loss improved from 1.66868 to 1.65836, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.5843 - sparse_categorical_accuracy: 0.6397 - val_loss: 1.6584 - val_sparse_categorical_accuracy: 0.6051 - learning_rate: 1.2500e-05
# Epoch 14/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5652 - sparse_categorical_accuracy: 0.6442
# Epoch 14: val_loss improved from 1.65836 to 1.65588, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.5652 - sparse_categorical_accuracy: 0.6442 - val_loss: 1.6559 - val_sparse_categorical_accuracy: 0.6055 - learning_rate: 6.2500e-06
# Epoch 15/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5623 - sparse_categorical_accuracy: 0.6439
# Epoch 15: val_loss improved from 1.65588 to 1.65502, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.5623 - sparse_categorical_accuracy: 0.6439 - val_loss: 1.6550 - val_sparse_categorical_accuracy: 0.6060 - learning_rate: 3.1250e-06
# Epoch 16/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5625 - sparse_categorical_accuracy: 0.6437
# Epoch 16: val_loss improved from 1.65502 to 1.65394, saving model to efficientnetb0_b128l10_best_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - loss: 1.5624 - sparse_categorical_accuracy: 0.6437 - val_loss: 1.6539 - val_sparse_categorical_accuracy: 0.6054 - learning_rate: 1.5625e-06
# Training time: 8.62 min

# %%
plot_history_comp(efficientnetb0_b128l5, efficientnetb0_b128l10,
                      model1_name="efficientnetb0_b128l5",
                      model2_name="efficientnetb0_b128l10")

# %% [markdown]
# ## ConvnextTiny L5

# %%
def create_datasets_convnext(base_path, train_df, val_df, batch_size):
    def preprocess_image(imageid, productid, label, augmented):
        def _load_image(image_path):
            img = tf.io.read_file(image_path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [224, 224])
            img = tf.keras.applications.convnext.preprocess_input(img)
            return img

        image_path = tf.strings.join([
            base_path,
            "image_",
            imageid,
            "_product_",
            productid,
            ".jpg"
        ])

        image = _load_image(image_path)

        def apply_augmentation(img):
            img = tf.image.random_flip_left_right(img)
            img = tf.image.random_brightness(img, max_delta=0.1)
            translations = tf.cast(tf.random.uniform([2], -10, 10), tf.int32)
            img = tf.roll(img, shift=translations[0], axis=0)  # vertical shift
            img = tf.roll(img, shift=translations[1], axis=1)  # horizontal shift
            return img

        image = tf.cond(augmented, lambda: apply_augmentation(image), lambda: image)

        return image, label

    # Prepare train dataset with augmentation flags from train_df
    train_image_ids = train_df["imageid"].astype(str).values
    train_product_ids = train_df["productid"].astype(str).values
    train_labels = train_df["label"].values
    train_aug_flags = train_df["augmented"].astype(bool).values

    train_ds = tf.data.Dataset.from_tensor_slices(
        (train_image_ids, train_product_ids, train_labels, train_aug_flags)
    )
    train_ds = train_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    # Prepare validation dataset (no augmentation)
    val_image_ids = val_df["imageid"].astype(str).values
    val_product_ids = val_df["productid"].astype(str).values
    val_labels = val_df["label"].values
    val_aug_flags = [False] * len(val_df)

    val_ds = tf.data.Dataset.from_tensor_slices(
        (val_image_ids, val_product_ids, val_labels, val_aug_flags)
    )
    val_ds = val_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds

# %%
train_ds, val_ds = create_datasets_convnext(base_path, df_train_balanced, val_df, 128)

# %%
# Model definition
base_model = ConvNeXtTiny(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-5:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

convnexttiny_l5 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

convnexttiny_l5.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'convnexttiny_l5_best_model.keras',               
    monitor='val_loss',            
    mode='min',                    
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.1,
        min_lr=1e-7,
        verbose=1
)

# %%
print("Model architecture:")
convnexttiny_l5.summary()
# Out:
# Model architecture:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ convnext_tiny (Functional)      │ (None, 7, 7, 768)      │    27,820,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_8      │ (None, 768)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 768)            │         3,072 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 27)             │         1,755 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,931,643 (106.55 MB)
#  Trainable params: 2,472,347 (9.43 MB)
#  Non-trainable params: 25,459,296 (97.12 MB)

# %%
import time
start_time = time.time()

convnexttiny_l5_history = convnexttiny_l5.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 6.3206 - sparse_categorical_accuracy: 0.1038
# Epoch 1: val_loss improved from inf to 4.74973, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 85s 123ms/step - loss: 6.3196 - sparse_categorical_accuracy: 0.1039 - val_loss: 4.7497 - val_sparse_categorical_accuracy: 0.3869 - learning_rate: 1.0000e-04
# Epoch 2/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.7214 - sparse_categorical_accuracy: 0.2940
# Epoch 2: val_loss improved from 4.74973 to 3.75138, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 4.7205 - sparse_categorical_accuracy: 0.2941 - val_loss: 3.7514 - val_sparse_categorical_accuracy: 0.4736 - learning_rate: 1.0000e-04
# Epoch 3/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 3.8627 - sparse_categorical_accuracy: 0.3737
# Epoch 3: val_loss improved from 3.75138 to 3.11970, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 3.8621 - sparse_categorical_accuracy: 0.3737 - val_loss: 3.1197 - val_sparse_categorical_accuracy: 0.5122 - learning_rate: 1.0000e-04
# Epoch 4/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 3.2635 - sparse_categorical_accuracy: 0.4232
# Epoch 4: val_loss improved from 3.11970 to 2.68708, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 3.2630 - sparse_categorical_accuracy: 0.4232 - val_loss: 2.6871 - val_sparse_categorical_accuracy: 0.5319 - learning_rate: 1.0000e-04
# Epoch 5/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.8404 - sparse_categorical_accuracy: 0.4541
# Epoch 5: val_loss improved from 2.68708 to 2.39131, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 2.8401 - sparse_categorical_accuracy: 0.4541 - val_loss: 2.3913 - val_sparse_categorical_accuracy: 0.5463 - learning_rate: 1.0000e-04
# Epoch 6/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.5406 - sparse_categorical_accuracy: 0.4791
# Epoch 6: val_loss improved from 2.39131 to 2.18409, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 2.5404 - sparse_categorical_accuracy: 0.4791 - val_loss: 2.1841 - val_sparse_categorical_accuracy: 0.5566 - learning_rate: 1.0000e-04
# Epoch 7/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.3178 - sparse_categorical_accuracy: 0.5032
# Epoch 7: val_loss improved from 2.18409 to 2.03657, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 2.3176 - sparse_categorical_accuracy: 0.5032 - val_loss: 2.0366 - val_sparse_categorical_accuracy: 0.5642 - learning_rate: 1.0000e-04
# Epoch 8/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.1628 - sparse_categorical_accuracy: 0.5176
# Epoch 8: val_loss improved from 2.03657 to 1.92552, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 2.1626 - sparse_categorical_accuracy: 0.5176 - val_loss: 1.9255 - val_sparse_categorical_accuracy: 0.5701 - learning_rate: 1.0000e-04
# Epoch 9/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.0401 - sparse_categorical_accuracy: 0.5327
# Epoch 9: val_loss improved from 1.92552 to 1.85087, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 2.0400 - sparse_categorical_accuracy: 0.5327 - val_loss: 1.8509 - val_sparse_categorical_accuracy: 0.5740 - learning_rate: 1.0000e-04
# Epoch 10/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.9521 - sparse_categorical_accuracy: 0.5410
# Epoch 10: val_loss improved from 1.85087 to 1.81632, saving model to convnexttiny_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 97ms/step - loss: 1.9520 - sparse_categorical_accuracy: 0.5410 - val_loss: 1.8163 - val_sparse_categorical_accuracy: 0.5743 - learning_rate: 5.0000e-05
# Epoch 11/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.9034 - sparse_categorical_accuracy: 0.5492
# Epoch 11: val_loss improved from 1.81632 to 1.78780, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 1.9034 - sparse_categorical_accuracy: 0.5492 - val_loss: 1.7878 - val_sparse_categorical_accuracy: 0.5756 - learning_rate: 5.0000e-05
# Epoch 12/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.5567
# Epoch 12: val_loss improved from 1.78780 to 1.77238, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.5567 - val_loss: 1.7724 - val_sparse_categorical_accuracy: 0.5777 - learning_rate: 2.5000e-05
# Epoch 13/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8477 - sparse_categorical_accuracy: 0.5598
# Epoch 13: val_loss improved from 1.77238 to 1.76702, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 1.8477 - sparse_categorical_accuracy: 0.5598 - val_loss: 1.7670 - val_sparse_categorical_accuracy: 0.5774 - learning_rate: 1.2500e-05
# Epoch 14/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8355 - sparse_categorical_accuracy: 0.5591
# Epoch 14: val_loss improved from 1.76702 to 1.76360, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.8355 - sparse_categorical_accuracy: 0.5591 - val_loss: 1.7636 - val_sparse_categorical_accuracy: 0.5779 - learning_rate: 6.2500e-06
# Epoch 15/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8417 - sparse_categorical_accuracy: 0.5593
# Epoch 15: val_loss improved from 1.76360 to 1.76207, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.8417 - sparse_categorical_accuracy: 0.5593 - val_loss: 1.7621 - val_sparse_categorical_accuracy: 0.5783 - learning_rate: 3.1250e-06
# Epoch 16/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8324 - sparse_categorical_accuracy: 0.5619
# Epoch 16: val_loss improved from 1.76207 to 1.76154, saving model to convnexttiny_l5_best_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.8324 - sparse_categorical_accuracy: 0.5619 - val_loss: 1.7615 - val_sparse_categorical_accuracy: 0.5787 - learning_rate: 1.5625e-06
# Training time: 14.80 min

# %% [markdown]
# ## ConvNextTiny L5 LR

# %%
# Model definition
base_model = ConvNeXtTiny(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-5:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

convnexttiny_l5lr = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

convnexttiny_l5lr.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'convnexttiny_l5lr_best_model.keras',               
    monitor='val_loss',             
    mode='min',                    
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.05,
        min_lr=1e-7,
        verbose=1
)

# %%
del convnexttiny_l5lr

# %%
import time
start_time = time.time()

convnexttiny_l5lr_history = convnexttiny_l5lr.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 6.3041 - sparse_categorical_accuracy: 0.1038
# Epoch 1: val_loss improved from inf to 4.71040, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 86s 124ms/step - loss: 6.3031 - sparse_categorical_accuracy: 0.1039 - val_loss: 4.7104 - val_sparse_categorical_accuracy: 0.3714 - learning_rate: 1.0000e-04
# Epoch 2/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.6843 - sparse_categorical_accuracy: 0.2913
# Epoch 2: val_loss improved from 4.71040 to 3.73280, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 4.6834 - sparse_categorical_accuracy: 0.2914 - val_loss: 3.7328 - val_sparse_categorical_accuracy: 0.4675 - learning_rate: 1.0000e-04
# Epoch 3/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 3.8226 - sparse_categorical_accuracy: 0.3743
# Epoch 3: val_loss improved from 3.73280 to 3.11123, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 3.8221 - sparse_categorical_accuracy: 0.3743 - val_loss: 3.1112 - val_sparse_categorical_accuracy: 0.5088 - learning_rate: 1.0000e-04
# Epoch 4/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 3.2487 - sparse_categorical_accuracy: 0.4163
# Epoch 4: val_loss improved from 3.11123 to 2.67776, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 3.2483 - sparse_categorical_accuracy: 0.4163 - val_loss: 2.6778 - val_sparse_categorical_accuracy: 0.5307 - learning_rate: 1.0000e-04
# Epoch 5/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.8326 - sparse_categorical_accuracy: 0.4518
# Epoch 5: val_loss improved from 2.67776 to 2.38303, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 95ms/step - loss: 2.8323 - sparse_categorical_accuracy: 0.4519 - val_loss: 2.3830 - val_sparse_categorical_accuracy: 0.5447 - learning_rate: 1.0000e-04
# Epoch 6/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.5329 - sparse_categorical_accuracy: 0.4806
# Epoch 6: val_loss improved from 2.38303 to 2.17308, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 95ms/step - loss: 2.5327 - sparse_categorical_accuracy: 0.4806 - val_loss: 2.1731 - val_sparse_categorical_accuracy: 0.5551 - learning_rate: 1.0000e-04
# Epoch 7/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.3143 - sparse_categorical_accuracy: 0.5014
# Epoch 7: val_loss improved from 2.17308 to 2.03020, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 2.3142 - sparse_categorical_accuracy: 0.5014 - val_loss: 2.0302 - val_sparse_categorical_accuracy: 0.5601 - learning_rate: 1.0000e-04
# Epoch 8/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.1624 - sparse_categorical_accuracy: 0.5147
# Epoch 8: val_loss improved from 2.03020 to 1.92272, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 2.1623 - sparse_categorical_accuracy: 0.5147 - val_loss: 1.9227 - val_sparse_categorical_accuracy: 0.5661 - learning_rate: 1.0000e-04
# Epoch 9/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.0408 - sparse_categorical_accuracy: 0.5296
# Epoch 9: val_loss improved from 1.92272 to 1.84817, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 2.0407 - sparse_categorical_accuracy: 0.5296 - val_loss: 1.8482 - val_sparse_categorical_accuracy: 0.5694 - learning_rate: 1.0000e-04
# Epoch 10/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.9438 - sparse_categorical_accuracy: 0.5401
# Epoch 10: val_loss improved from 1.84817 to 1.79144, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.9437 - sparse_categorical_accuracy: 0.5402 - val_loss: 1.7914 - val_sparse_categorical_accuracy: 0.5744 - learning_rate: 1.0000e-04
# Epoch 11/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.5494
# Epoch 11: val_loss improved from 1.79144 to 1.75138, saving model to convnexttiny_l5lr_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 54s 96ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.5495 - val_loss: 1.7514 - val_sparse_categorical_accuracy: 0.5756 - learning_rate: 1.0000e-04
# Epoch 12/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8103 - sparse_categorical_accuracy: 0.5619
# Epoch 12: val_loss improved from 1.75138 to 1.72191, saving model to convnexttiny_l5lr_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.8103 - sparse_categorical_accuracy: 0.5619 - val_loss: 1.7219 - val_sparse_categorical_accuracy: 0.5814 - learning_rate: 5.0000e-05
# Epoch 13/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.7857 - sparse_categorical_accuracy: 0.5677
# Epoch 13: val_loss improved from 1.72191 to 1.70777, saving model to convnexttiny_l5lr_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 95ms/step - loss: 1.7857 - sparse_categorical_accuracy: 0.5677 - val_loss: 1.7078 - val_sparse_categorical_accuracy: 0.5805 - learning_rate: 5.0000e-05
# Epoch 14/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.7582 - sparse_categorical_accuracy: 0.5734
# Epoch 14: val_loss improved from 1.70777 to 1.69668, saving model to convnexttiny_l5lr_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.7582 - sparse_categorical_accuracy: 0.5734 - val_loss: 1.6967 - val_sparse_categorical_accuracy: 0.5828 - learning_rate: 2.5000e-05
# Epoch 15/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.7436 - sparse_categorical_accuracy: 0.5735
# Epoch 15: val_loss improved from 1.69668 to 1.69124, saving model to convnexttiny_l5lr_best_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.7436 - sparse_categorical_accuracy: 0.5735 - val_loss: 1.6912 - val_sparse_categorical_accuracy: 0.5838 - learning_rate: 1.2500e-05
# Epoch 16/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.7383 - sparse_categorical_accuracy: 0.5782
# Epoch 16: val_loss improved from 1.69124 to 1.68916, saving model to convnexttiny_l5lr_best_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 96ms/step - loss: 1.7383 - sparse_categorical_accuracy: 0.5782 - val_loss: 1.6892 - val_sparse_categorical_accuracy: 0.5835 - learning_rate: 6.2500e-06
# Epoch 17/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.7314 - sparse_categorical_accuracy: 0.5787
# Epoch 17: val_loss improved from 1.68916 to 1.68782, saving model to convnexttiny_l5lr_best_model.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 53s 95ms/step - loss: 1.7314 - sparse_categorical_accuracy: 0.5787 - val_loss: 1.6878 - val_sparse_categorical_accuracy: 0.5834 - learning_rate: 3.1250e-06
# Training time: 15.67 min

# %%
plot_history_comp(convnexttiny_l5, convnexttiny_l5lr,
                      model1_name="convnexttiny_l5",
                      model2_name="convnexttiny_l5lr")

# %% [markdown]
# ## DenseNet201 L5

# %%
from tensorflow.keras.applications import DenseNet201

def create_datasets_densenet(base_path, train_df, val_df, batch_size):
    def preprocess_image(imageid, productid, label, augmented):
        def _load_image(image_path):
            img = tf.io.read_file(image_path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [224, 224])
            img = tf.keras.applications.densenet.preprocess_input(img)
            return img

        image_path = tf.strings.join([
            base_path,
            "image_",
            imageid,
            "_product_",
            productid,
            ".jpg"
        ])

        image = _load_image(image_path)

        def apply_augmentation(img):
            img = tf.image.random_flip_left_right(img)
            img = tf.image.random_brightness(img, max_delta=0.1)
            translations = tf.cast(tf.random.uniform([2], -10, 10), tf.int32)
            img = tf.roll(img, shift=translations[0], axis=0)  # vertical shift
            img = tf.roll(img, shift=translations[1], axis=1)  # horizontal shift
            return img

        image = tf.cond(augmented, lambda: apply_augmentation(image), lambda: image)

        return image, label

    # Prepare train dataset with augmentation flags from train_df
    train_image_ids = train_df["imageid"].astype(str).values
    train_product_ids = train_df["productid"].astype(str).values
    train_labels = train_df["label"].values
    train_aug_flags = train_df["augmented"].astype(bool).values

    train_ds = tf.data.Dataset.from_tensor_slices(
        (train_image_ids, train_product_ids, train_labels, train_aug_flags)
    )
    train_ds = train_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    # Prepare validation dataset (no augmentation)
    val_image_ids = val_df["imageid"].astype(str).values
    val_product_ids = val_df["productid"].astype(str).values
    val_labels = val_df["label"].values
    val_aug_flags = [False] * len(val_df)

    val_ds = tf.data.Dataset.from_tensor_slices(
        (val_image_ids, val_product_ids, val_labels, val_aug_flags)
    )
    val_ds = val_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds

# %%
train_ds, val_ds = create_datasets_densenet(base_path, df_train_balanced, val_df, 128)

# %%
# Model definition
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-5:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

densenet201_l5 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

densenet201_l5.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'densenet201_l5_best_model.keras',               
    monitor='val_loss',             
    mode='min',                     
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_delta=0.1,
        min_lr=1e-7,
        verbose=1
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print("Model architecture:")
convnexttiny_l5.summary()
# Out:
# Model architecture:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ convnext_tiny (Functional)      │ (None, 7, 7, 768)      │    27,820,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_9      │ (None, 768)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 768)            │         3,072 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 128)            │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 27)             │         1,755 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,876,339 (125.41 MB)
#  Trainable params: 2,472,347 (9.43 MB)
#  Non-trainable params: 25,459,296 (97.12 MB)
#  Optimizer params: 4,944,696 (18.86 MB)

# %%
import time
start_time = time.time()
# Train
densenet201_l5_history = densenet201_l5.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 5.8765 - sparse_categorical_accuracy: 0.0986
# Epoch 1: val_loss improved from inf to 3.92026, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 176s 226ms/step - loss: 5.8752 - sparse_categorical_accuracy: 0.0987 - val_loss: 3.9203 - val_sparse_categorical_accuracy: 0.3795 - learning_rate: 1.0000e-04
# Epoch 2/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 3.9481 - sparse_categorical_accuracy: 0.2790
# Epoch 2: val_loss improved from 3.92026 to 3.14750, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 3.9475 - sparse_categorical_accuracy: 0.2791 - val_loss: 3.1475 - val_sparse_categorical_accuracy: 0.4554 - learning_rate: 1.0000e-04
# Epoch 3/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 3.3127 - sparse_categorical_accuracy: 0.3516
# Epoch 3: val_loss improved from 3.14750 to 2.73851, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 3.3123 - sparse_categorical_accuracy: 0.3516 - val_loss: 2.7385 - val_sparse_categorical_accuracy: 0.4868 - learning_rate: 1.0000e-04
# Epoch 4/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.9229 - sparse_categorical_accuracy: 0.3938
# Epoch 4: val_loss improved from 2.73851 to 2.46223, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 2.9227 - sparse_categorical_accuracy: 0.3939 - val_loss: 2.4622 - val_sparse_categorical_accuracy: 0.5063 - learning_rate: 1.0000e-04
# Epoch 5/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 2.6545 - sparse_categorical_accuracy: 0.4203
# Epoch 5: val_loss improved from 2.46223 to 2.27918, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 62s 110ms/step - loss: 2.6543 - sparse_categorical_accuracy: 0.4203 - val_loss: 2.2792 - val_sparse_categorical_accuracy: 0.5169 - learning_rate: 1.0000e-04
# Epoch 6/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.4535 - sparse_categorical_accuracy: 0.4415
# Epoch 6: val_loss improved from 2.27918 to 2.14551, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 2.4534 - sparse_categorical_accuracy: 0.4415 - val_loss: 2.1455 - val_sparse_categorical_accuracy: 0.5269 - learning_rate: 1.0000e-04
# Epoch 7/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 2.3202 - sparse_categorical_accuracy: 0.4598
# Epoch 7: val_loss improved from 2.14551 to 2.05488, saving model to densenet201_l5_best_model.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 62s 110ms/step - loss: 2.3201 - sparse_categorical_accuracy: 0.4598 - val_loss: 2.0549 - val_sparse_categorical_accuracy: 0.5312 - learning_rate: 1.0000e-04
# Epoch 8/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.2253 - sparse_categorical_accuracy: 0.4698
# Epoch 8: val_loss improved from 2.05488 to 2.01433, saving model to densenet201_l5_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 2.2253 - sparse_categorical_accuracy: 0.4698 - val_loss: 2.0143 - val_sparse_categorical_accuracy: 0.5370 - learning_rate: 5.0000e-05
# Epoch 9/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 2.1715 - sparse_categorical_accuracy: 0.4772
# Epoch 9: val_loss improved from 2.01433 to 1.97921, saving model to densenet201_l5_best_model.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 62s 110ms/step - loss: 2.1714 - sparse_categorical_accuracy: 0.4772 - val_loss: 1.9792 - val_sparse_categorical_accuracy: 0.5389 - learning_rate: 5.0000e-05
# Epoch 10/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.1321 - sparse_categorical_accuracy: 0.4849
# Epoch 10: val_loss improved from 1.97921 to 1.96530, saving model to densenet201_l5_best_model.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 108ms/step - loss: 2.1321 - sparse_categorical_accuracy: 0.4849 - val_loss: 1.9653 - val_sparse_categorical_accuracy: 0.5396 - learning_rate: 2.5000e-05
# Epoch 11/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.1174 - sparse_categorical_accuracy: 0.4892
# Epoch 11: val_loss improved from 1.96530 to 1.95632, saving model to densenet201_l5_best_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 2.1173 - sparse_categorical_accuracy: 0.4892 - val_loss: 1.9563 - val_sparse_categorical_accuracy: 0.5404 - learning_rate: 1.2500e-05
# Epoch 12/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.1027 - sparse_categorical_accuracy: 0.4864
# Epoch 12: val_loss improved from 1.95632 to 1.95149, saving model to densenet201_l5_best_model.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 108ms/step - loss: 2.1027 - sparse_categorical_accuracy: 0.4864 - val_loss: 1.9515 - val_sparse_categorical_accuracy: 0.5406 - learning_rate: 6.2500e-06
# Epoch 13/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.1023 - sparse_categorical_accuracy: 0.4872
# Epoch 13: val_loss improved from 1.95149 to 1.94966, saving model to densenet201_l5_best_model.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 61s 109ms/step - loss: 2.1022 - sparse_categorical_accuracy: 0.4872 - val_loss: 1.9497 - val_sparse_categorical_accuracy: 0.5402 - learning_rate: 3.1250e-06
# Epoch 14/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 2.1023 - sparse_categorical_accuracy: 0.4867
# Epoch 14: val_loss improved from 1.94966 to 1.94903, saving model to densenet201_l5_best_model.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 60s 108ms/step - loss: 2.1022 - sparse_categorical_accuracy: 0.4867 - val_loss: 1.9490 - val_sparse_categorical_accuracy: 0.5401 - learning_rate: 1.5625e-06
# Training time: 16.20 min

# %% [markdown]
# ## DenseNet201 L5 LRc

# %%
# Model definition
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

for layer in base_model.layers[-5:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

densenet201_l5lr = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

densenet201_l5lr.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'densenet201_l5lr_best_model.keras',               
    monitor='val_loss',            
    mode='min',                    
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_delta=0.05,
        min_lr=1e-7,
        verbose=1
)

# %%
import time
start_time = time.time()

densenet201_l5lr_history = densenet201_l5lr.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# KeyboardInterrupt

# %%
plot_history_comp(densenet201_l5, densenet201_l5lr,
                      model1_name="densenet201_l5",
                      model2_name="densenet201_l5lr")

# %% [markdown]
# ## From scratch

# %%
def create_datasets_generic(base_path, train_df, val_df, batch_size):
    def preprocess_image(imageid, productid, label, augmented):
        def _load_image(image_path):
            img = tf.io.read_file(image_path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [224, 224])
            return img

        image_path = tf.strings.join([
            base_path,
            "image_",
            imageid,
            "_product_",
            productid,
            ".jpg"
        ])

        image = _load_image(image_path)

        def apply_augmentation(img):
            img = tf.image.random_flip_left_right(img)
            img = tf.image.random_brightness(img, max_delta=0.1)
            translations = tf.cast(tf.random.uniform([2], -10, 10), tf.int32)
            img = tf.roll(img, shift=translations[0], axis=0)  # vertical shift
            img = tf.roll(img, shift=translations[1], axis=1)  # horizontal shift
            return img

        image = tf.cond(augmented, lambda: apply_augmentation(image), lambda: image)

        return image, label

    # Prepare train dataset with augmentation flags from train_df
    train_image_ids = train_df["imageid"].astype(str).values
    train_product_ids = train_df["productid"].astype(str).values
    train_labels = train_df["label"].values
    train_aug_flags = train_df["augmented"].astype(bool).values

    train_ds = tf.data.Dataset.from_tensor_slices(
        (train_image_ids, train_product_ids, train_labels, train_aug_flags)
    )
    train_ds = train_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    # Prepare validation dataset (no augmentation)
    val_image_ids = val_df["imageid"].astype(str).values
    val_product_ids = val_df["productid"].astype(str).values
    val_labels = val_df["label"].values
    val_aug_flags = [False] * len(val_df)

    val_ds = tf.data.Dataset.from_tensor_slices(
        (val_image_ids, val_product_ids, val_labels, val_aug_flags)
    )
    val_ds = val_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds

# %%
train_ds, val_ds = create_datasets_generic(base_path, df_train_balanced, val_df, 128)

# %%
cnn_from_scratch = models.Sequential([
    # Block 1
    layers.Conv2D(32, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(224,224,3)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),

    # Block 2
    layers.Conv2D(64, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),

    # Block 3
    layers.Conv2D(128, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),

    #Block 4
    layers.Conv2D(256, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),

    # Classification Head
    layers.Flatten(),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
cnn_from_scratch.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Callbacks

checkpoint = ModelCheckpoint(
    'cnn_from_scratch_best_model.keras',                
    monitor='val_loss',             
    mode='min',                    
    save_best_only=True,            
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.02,
    restore_best_weights=True
)

learning_rate =  ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        min_delta=0.05,
        min_lr=1e-7,
        verbose=1
)

# %%
print("Model architecture:")
cnn_from_scratch.summary()
# Out:
# Model architecture:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_19 (Conv2D)              │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_24 (Activation)      │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_25 (Activation)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_26 (Activation)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_27 (Activation)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 512)            │    25,690,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_28 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 27)             │        13,851 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,096,859 (99.55 MB)
#  Trainable params: 26,094,875 (99.54 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
import time
start_time = time.time()

cnn_from_scratch_history = cnn_from_scratch.fit(train_ds,
          validation_data=val_ds,
          epochs=20,
          callbacks=[early_stop, checkpoint, learning_rate])

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_min = elapsed_time / 60
print(f"Training time: {elapsed_time_min:.2f} min")
# Out:
# Epoch 1/20
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 7.5557 - sparse_categorical_accuracy: 0.1998
# Epoch 1: val_loss improved from inf to 6.17652, saving model to cnn_from_scratch_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 49s 73ms/step - loss: 7.5515 - sparse_categorical_accuracy: 0.1999 - val_loss: 6.1765 - val_sparse_categorical_accuracy: 0.0319 - learning_rate: 0.0010
# Epoch 2/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 4.0555 - sparse_categorical_accuracy: 0.2838
# Epoch 2: val_loss did not improve from 6.17652
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 4.0550 - sparse_categorical_accuracy: 0.2838 - val_loss: 6.5164 - val_sparse_categorical_accuracy: 0.0311 - learning_rate: 0.0010
# Epoch 3/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.6656 - sparse_categorical_accuracy: 0.3194
# Epoch 3: val_loss did not improve from 6.17652
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 3.6654 - sparse_categorical_accuracy: 0.3194 - val_loss: 7.3009 - val_sparse_categorical_accuracy: 0.0207 - learning_rate: 0.0010
# Epoch 4/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.0364 - sparse_categorical_accuracy: 0.3736
# Epoch 4: val_loss improved from 6.17652 to 3.88548, saving model to cnn_from_scratch_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 34s 61ms/step - loss: 3.0360 - sparse_categorical_accuracy: 0.3736 - val_loss: 3.8855 - val_sparse_categorical_accuracy: 0.1880 - learning_rate: 5.0000e-04
# Epoch 5/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.8478 - sparse_categorical_accuracy: 0.3991
# Epoch 5: val_loss improved from 3.88548 to 3.66565, saving model to cnn_from_scratch_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 34s 61ms/step - loss: 2.8476 - sparse_categorical_accuracy: 0.3991 - val_loss: 3.6656 - val_sparse_categorical_accuracy: 0.2110 - learning_rate: 5.0000e-04
# Epoch 6/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.7588 - sparse_categorical_accuracy: 0.4171
# Epoch 6: val_loss improved from 3.66565 to 3.37655, saving model to cnn_from_scratch_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 34s 61ms/step - loss: 2.7587 - sparse_categorical_accuracy: 0.4171 - val_loss: 3.3765 - val_sparse_categorical_accuracy: 0.2909 - learning_rate: 5.0000e-04
# Epoch 7/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.7341 - sparse_categorical_accuracy: 0.4229
# Epoch 7: val_loss did not improve from 3.37655
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 2.7340 - sparse_categorical_accuracy: 0.4229 - val_loss: 5.8201 - val_sparse_categorical_accuracy: 0.1149 - learning_rate: 5.0000e-04
# Epoch 8/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.6759 - sparse_categorical_accuracy: 0.4357
# Epoch 8: val_loss did not improve from 3.37655
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 2.6758 - sparse_categorical_accuracy: 0.4357 - val_loss: 7.6123 - val_sparse_categorical_accuracy: 0.0916 - learning_rate: 5.0000e-04
# Epoch 9/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.4205 - sparse_categorical_accuracy: 0.4717
# Epoch 9: val_loss improved from 3.37655 to 2.53151, saving model to cnn_from_scratch_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 34s 61ms/step - loss: 2.4202 - sparse_categorical_accuracy: 0.4718 - val_loss: 2.5315 - val_sparse_categorical_accuracy: 0.4150 - learning_rate: 2.5000e-04
# Epoch 10/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.2551 - sparse_categorical_accuracy: 0.4987
# Epoch 10: val_loss did not improve from 2.53151
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 58ms/step - loss: 2.2550 - sparse_categorical_accuracy: 0.4988 - val_loss: 2.7593 - val_sparse_categorical_accuracy: 0.3728 - learning_rate: 2.5000e-04
# Epoch 11/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.2120 - sparse_categorical_accuracy: 0.5107
# Epoch 11: val_loss did not improve from 2.53151
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 2.2120 - sparse_categorical_accuracy: 0.5107 - val_loss: 2.5716 - val_sparse_categorical_accuracy: 0.4247 - learning_rate: 2.5000e-04
# Epoch 12/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.0371 - sparse_categorical_accuracy: 0.5491
# Epoch 12: val_loss improved from 2.53151 to 2.32668, saving model to cnn_from_scratch_best_model.keras
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 34s 61ms/step - loss: 2.0368 - sparse_categorical_accuracy: 0.5492 - val_loss: 2.3267 - val_sparse_categorical_accuracy: 0.4636 - learning_rate: 1.2500e-04
# Epoch 13/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.8649 - sparse_categorical_accuracy: 0.5792
# Epoch 13: val_loss did not improve from 2.32668
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 1.8647 - sparse_categorical_accuracy: 0.5793 - val_loss: 2.4586 - val_sparse_categorical_accuracy: 0.4192 - learning_rate: 1.2500e-04
# Epoch 14/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.8021 - sparse_categorical_accuracy: 0.5965
# Epoch 14: val_loss did not improve from 2.32668
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 1.8020 - sparse_categorical_accuracy: 0.5965 - val_loss: 4.0812 - val_sparse_categorical_accuracy: 0.2517 - learning_rate: 1.2500e-04
# Epoch 15/20
# 556/557 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.6557 - sparse_categorical_accuracy: 0.6343
# Epoch 15: val_loss did not improve from 2.32668
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - loss: 1.6554 - sparse_categorical_accuracy: 0.6344 - val_loss: 7.1451 - val_sparse_categorical_accuracy: 0.1395 - learning_rate: 6.2500e-05
# Training time: 8.58 min

# %%
plot_history(cnn_from_scratch_history.history)

# %%
cnn_from_scratch_history.history
# Out:
# {'loss': [5.258408546447754,
#   3.92529296875,
#   3.6016018390655518,
#   2.9295949935913086,
#   2.818491220474243,
#   2.743262767791748,
#   2.7099406719207764,
#   2.6593964099884033,
#   2.322327136993408,
#   2.2338664531707764,
#   2.196995258331299,
#   1.9424782991409302,
#   1.8218333721160889,
#   1.7718603610992432,
#   1.5791401863098145],
#  'sparse_categorical_accuracy': [0.23425890505313873,
#   0.2942597568035126,
#   0.3243303894996643,
#   0.3839379847049713,
#   0.4045422077178955,
#   0.41818001866340637,
#   0.4265509247779846,
#   0.43760445713996887,
#   0.4856388568878174,
#   0.5043469667434692,
#   0.5150914788246155,
#   0.5693478584289551,
#   0.5913987755775452,
#   0.6045730710029602,
#   0.6544193029403687],
#  'val_loss': [6.176519870758057,
#   6.516442775726318,
#   7.300868034362793,
#   3.8854782581329346,
#   3.6656477451324463,
#   3.376546621322632,
#   5.820057392120361,
#   7.612295627593994,
#   2.5315091609954834,
#   2.7593069076538086,
#   2.5716335773468018,
#   2.3266823291778564,
#   2.4586260318756104,
#   4.0812249183654785,
#   7.145097255706787],
#  'val_sparse_categorical_accuracy': [0.031889718025922775,
#   0.031061412766575813,
#   0.02070760913193226,
#   0.1880250871181488,
#   0.21104010939598083,
#   0.29091233015060425,
#   0.11489764600992203,
#   0.09164595603942871,
#   0.4149804711341858,
#   0.37279611825942993,
#   0.42468348145484924,
#   0.46355462074279785,
#   0.4191811680793762,
#   0.251745343208313,
#   0.13945095241069794],
#  'learning_rate': [0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   6.25000029685907e-05]}

# %%
val_loss = cnn_from_scratch_history.history['val_loss']
learning_rate = cnn_from_scratch_history.history.get('learning_rate')

epochs = range(1, len(val_loss) + 1)

fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:blue'
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Validation Loss', color=color)
ax1.plot(epochs, val_loss, marker='o', linestyle='-', color=color, label='Val Loss')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:red'
ax2.set_ylabel('Learning Rate', color=color)
ax2.plot(epochs, learning_rate, marker='x', linestyle='--', color=color, label='Learning Rate')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_yscale('log')

plt.title('Validation Loss and Learning Rate per Epoch')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Save histories

# %%
import json
all_histories = {
    name: obj.history
    for name, obj in globals().items()
    if name.endswith('_history') and hasattr(obj, 'history')
}

for name, history_dict in all_histories.items():
    with open(f"{name}.json", "w") as f:
        json.dump(history_dict, f)

# %%
import os
import zipfile
from google.colab import files

keras_files = [f for f in os.listdir('.') if f.endswith('.keras')]

with zipfile.ZipFile('keras_models.zip', 'w') as zipf:
    for file in keras_files:
        zipf.write(file)

files.download('keras_models.zip')
